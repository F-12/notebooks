# %% [markdown]
# ![code-wallpaper-1280x800.jpg](attachment:code-wallpaper-1280x800.jpg)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#关于作者" data-toc-modified-id="关于作者-1">关于作者</a></span></li><li><span><a href="#关于站点" data-toc-modified-id="关于站点-2">关于站点</a></span></li></ul></div>

# %% [markdown]
# # 关于作者
#
# ![thumb_IMG_0714_1024.jpg](attachment:thumb_IMG_0714_1024.jpg)

# %% [markdown]
# # 关于站点
#
# [看这里](README.slides.html)
